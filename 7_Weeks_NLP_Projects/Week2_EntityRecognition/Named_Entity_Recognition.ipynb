# %% [markdown]
# ## Named Entity Recognition
#
# Named entities are the objects in the real world that have a name. For example - a person, an organization, a product, a country etc. Using spaCy, we will use data from tripadvisor web pages to extract named entities in this project.
#
# TODO: Incorporate word sense disambiguation

# %%
#https://www.tripadvisor.com/ExperiencesInsights/travelers/top-travel-trends-2018
sentence = 'As a tour operator or attraction owner, staying on top of trends in the rapidly changing travel landscape is critical to helping you make important decisions about your business, including how to better satisfy customers and where to invest your resources. To help you, we’ve taken a look at our own booking data and traveler surveys, combined with research from reputable industry resources, to provide you insight into this year’s top travel trends—plus key takeaways for your business.'

# %% [markdown]
# ### Installation
#
# python -m spacy download en_core_web_lg

# %% [markdown]
# We are going to use spaCy for NER in our text. spaCy's model is trained based on [Onenote5 corpus](https://catalog.ldc.upenn.edu/ldc2013t19). spaCy also has a NER model that is trained on Wikipedia but that model does less granular classification. The model trained on Onenote5 corpus supports below entity
#
# ### Entity
#
# ![caption](files/Spacy-Onenote5-Entity.png)
#
# More about it is here https://spacy.io/api/annotation#section-named-entities

# %%
import spacy
from spacy import displacy
from collections import Counter
from spacy.lang.en import English
import en_core_web_lg

# %% [markdown]
# spaCy has language models (https://spacy.io/usage/models) that we can use for entity recognition. For our purpose, we will use `en_core_web_lg` model. In general `lg` models are expected to perform better as they incorporate a larger dataset. This model is used for `vocabulary`, `entities`, `syntax` and `vector` recognition.

# %%
#load the spaCy model
nlp = en_core_web_lg.load()

#generate the document object
doc = nlp(sentence)

#now lets see what are the entities that we have in the input sentence
print([(X.text, X.label_) for X in doc.ents])
# Out:
# [('year', 'DATE')]

# %% [markdown]
# ### BILOU Tagging scheme
#
# There are different tagging schemes in Natural Language Processing tasks - `IOB` is one of the common ones that is used in `NLTK`.
#
# I - prefix before a tag indicates that the tag is inside a chunk
#
# O - tag indicates that a token belongs to no chunk
#
# B- prefix before a tag indicates that the tag is the beginning of a chunk
#
#
# #### Why BILOU not IOB
# Instead of `IOB`, spaCy uses `BILOU` tagging scheme. As mentioned in the spaCy doc "There are several coding schemes for encoding entity annotations as token tags. These coding schemes are equally expressive, but not necessarily equally learnable. Ratinov and Roth showed that the minimal Begin, In, Out scheme was more difficult to learn than the BILUO scheme that we use, which explicitly marks boundary tokens."
#
# ![caption](files/BILUO.png)

# %%
print([(X, X.ent_iob_, X.ent_type_) for X in doc])
# Out:
# [(As, 'O', ''), (a, 'O', ''), (tour, 'O', ''), (operator, 'O', ''), (or, 'O', ''), (attraction, 'O', ''), (owner, 'O', ''), (,, 'O', ''), (staying, 'O', ''), (on, 'O', ''), (top, 'O', ''), (of, 'O', ''), (trends, 'O', ''), (in, 'O', ''), (the, 'O', ''), (rapidly, 'O', ''), (changing, 'O', ''), (travel, 'O', ''), (landscape, 'O', ''), (is, 'O', ''), (critical, 'O', ''), (to, 'O', ''), (helping, 'O', ''), (you, 'O', ''), (make, 'O', ''), (important, 'O', ''), (decisions, 'O', ''), (about, 'O', ''), (your, 'O', ''), (business, 'O', ''), (,, 'O', ''), (including, 'O', ''), (how, 'O', ''), (to, 'O', ''), (better, 'O', ''), (satisfy, 'O', ''), (customers, 'O', ''), (and, 'O', ''), (where, 'O', ''), (to, 'O', ''), (invest, 'O', ''), (your, 'O', ''), (resources, 'O', ''), (., 'O', ''), (To, 'O', ''), (help, 'O', ''), (you, 'O', ''), (,, 'O', ''), (we, 'O', ''), (’ve, 'O', ''), (taken, 'O', ''), (a, 'O', ''), (look, 'O', ''), (at, 'O', ''), (our, 'O', ''), (own, 'O', ''), (booking, 'O', ''), (data, 'O', ''), (and, 'O', ''), (traveler, 'O', ''), (surveys, 'O', ''), (,, 'O', ''), (combined, 'O', ''), (with, 'O', ''), (research, 'O', ''), (from, 'O', ''), (reputable, 'O', ''), (industry, 'O', ''), (resources, 'O', ''), (,, 'O', ''), (to, 'O', ''), (provide, 'O', ''), (you, 'O', ''), (insight, 'O', ''), (into, 'O', ''), (this, 'O', ''), (year, 'B', 'DATE'), (’s, 'O', ''), (top, 'O', ''), (travel, 'O', ''), (trends, 'O', ''), (—, 'O', ''), (plus, 'O', ''), (key, 'O', ''), (takeaways, 'O', ''), (for, 'O', ''), (your, 'O', ''), (business, 'O', ''), (., 'O', '')]

# %%
from bs4 import BeautifulSoup
import requests
import re

# %%
#this determines how/what you extract from an article
def url_to_string(url):
    res = requests.get(url)
    html = res.text
    soup = BeautifulSoup(html, 'html5lib')
    for script in soup(["script", "style", 'aside']):
        script.extract()
    return " ".join(re.split(r'[\n\t]+', soup.get_text()))

# %%
article = url_to_string('https://www.tripadvisor.com/ExperiencesInsights/travelers/top-travel-trends-2018')
#this site returned 403 forbidden https://weekendsherpa.com/stories/hike-san-franciscos-grand-walk-sutra-baths-to-crissy-field/
#https://www.tripadvisor.com/ExperiencesInsights/
article = nlp(article)
len(article.ents)
# Out:
# 233

# %%
#show the Spacy Entity Labels
labels = [x.label_ for x in article.ents]
Counter(labels)
# Out:
# Counter({'ORG': 67, 'DATE': 56, 'CARDINAL': 20, 'GPE': 20, 'PRODUCT': 16, 'PERCENT': 16, 'PERSON': 11, 'WORK_OF_ART': 7, 'MONEY': 5, 'ORDINAL': 3, 'FAC': 3, 'EVENT': 2, 'TIME': 2, 'LOC': 2, 'QUANTITY': 2, 'NORP': 1})

# %%
items = [x.text for x in article.ents]
Counter(items).most_common(3)
# Out:
# [('TripAdvisor', 13), ('300w', 9), ('srcset="https://mk0attractionsiexgba.kinstacdn.com', 8)]

# %%
#print the (text, label) touple
pair = [(x.text, x.label_) for x in article.ents]
print(pair)
# Out:
# [('the Year - TripAdvisor Experiences', 'EVENT'), ('Page   ', 'PERSON'), ('the Year–', 'EVENT'), ('May 8', 'DATE'), ('year', 'DATE'), ('1', 'CARDINAL'), ('Tours', 'GPE'), ('uploads/2017/11/camels-1024x683.jpg"', 'WORK_OF_ART'), ('1024w', 'DATE'), ('300w', 'PRODUCT'), ('1080w', 'DATE'), ('817px)', 'ORG'), ('$135 billion', 'MONEY'), ('third', 'ORDINAL'), ('$174 billion', 'MONEY'), ('2020', 'DATE'), ('$765 million', 'MONEY'), ('more than 200', 'CARDINAL'), ('2005', 'DATE'), ('2018', 'DATE'), ('68%', 'PERCENT'), ('59%', 'PERCENT'), ('2017', 'DATE'), ('Millennials', 'ORG'), ('79%', 'PERCENT'), ('TripBarometer', 'PRODUCT'), ('2017', 'DATE'), ('TripAdvisor', 'ORG'), ('Tours', 'GPE'), ('the years ahead', 'DATE'), ('srcset="https://mk0attractionsiexgba.kinstacdn.com', 'ORG'), ('1024w', 'DATE'), ('300w', 'PRODUCT'), ('https://mk0attractionsiexgba.kinstacdn.com/wp-content/uploads/2018/01/booking-online-768x514.jpg', 'ORG'), ('https://mk0attractionsiexgba.kinstacdn.com/wp-content/uploads/2018/01/booking-online-1080x723.jpg', 'FAC'), ('1480w', 'DATE'), ('817px)', 'ORG'), ('the past two decades', 'DATE'), ('TripBarometer', 'ORG'), ('nearly 75%', 'PERCENT'), ('two-thirds', 'CARDINAL'), ('2020', 'DATE'), ('Phocuswright', 'PERSON'), ('10B', 'MONEY'), ('2014', 'DATE'), ('$27 billion', 'MONEY'), ('TripAdvisor', 'ORG'), ('SEO', 'ORG'), ('Google Adwords', 'ORG'), ('seasons remain July', 'DATE'), ('September', 'DATE'), ('image-25375', 'DATE'), ('srcset="https://mk0attractionsiexgba.kinstacdn.com', 'ORG'), ('uploads/2018/01/italy-3', 'ORG'), ('1024w', 'DATE'), ('https://mk0attractionsiexgba.kinstacdn.com/wp-content/uploads/2018/01/italy-3-300x200.jpg', 'ORG'), ('300w', 'PRODUCT'), ('https://mk0attractionsiexgba.kinstacdn.com/wp-content/uploads/2018/01/italy-3-768x512.jpg', 'ORG'), ('https://mk0attractionsiexgba.kinstacdn.com/wp-content/uploads/2018/01/italy-3-1080x720.jpg', 'PERSON'), ('818px', 'CARDINAL'), ('the busiest season', 'DATE'), ('July through September', 'DATE'), ('the summer months', 'DATE'), ('About 35%', 'PERCENT'), ('28%', 'PERCENT'), ('April through June', 'DATE'), ('59%', 'PERCENT'), ('between one and three months before', 'DATE'), ('the summer', 'DATE'), ('Last-minute', 'TIME'), ('alt=', 'WORK_OF_ART'), ('width="815" height="611', 'ORG'), ('srcset="https://mk0attractionsiexgba.kinstacdn.com', 'ORG'), ('1024w', 'DATE'), ('300w', 'ORG'), ('768w', 'PRODUCT'), ('510w', 'PRODUCT'), ('1080w', 'DATE'), ('1440w', 'DATE'), ('815px', 'PERSON'), ('100vw', 'GPE'), ('815px"', 'GPE'), ('previous years', 'DATE'), ('between one and three months', 'DATE'), ('These days', 'DATE'), ('2 weeks', 'DATE'), ('TripAdvisor', 'ORG'), ('70%', 'PERCENT'), ('the last year', 'DATE'), ('More than half', 'CARDINAL'), ('three days', 'DATE'), ('last-minute', 'TIME'), ('Bokun', 'ORG'), ('Fareharbor', 'PERSON'), ('Rezdy', 'NORP'), ('Trekksoft', 'GPE'), ('TourCMS', 'ORG'), ('Rezgo', 'PERSON'), ('Bokun', 'ORG'), ('3-month', 'DATE'), ('just 0.1%', 'PERCENT'), ('–', 'DATE'), ('Experiential”', 'LOC'), ('image-25374', 'DATE'), ('width="815"', 'WORK_OF_ART'), ('srcset="https://mk0attractionsiexgba.kinstacdn.com', 'ORG'), ('1024w', 'DATE'), ('300w', 'CARDINAL'), ('768w', 'PRODUCT'), ('815px', 'PERSON'), ('100vw', 'GPE'), ('815px"', 'GPE'), ('Skift', 'ORG'), ('the last few years', 'DATE'), ('TripAdvisor', 'ORG'), ('today', 'DATE'), ('Millennial', 'ORG'), ('uploads/2017/11/travelers-1024x683.jpg', 'PERSON'), ('width="815" height="543">', 'WORK_OF_ART'), ('Millennials', 'ORG'), ('between 1980 and 2000', 'DATE'), ('today', 'DATE'), ('travel—79%', 'PERCENT'), ('2018', 'DATE'), ('68%', 'PERCENT'), ('Boomers—', 'ORG'), ('Millennials', 'ORG'), ('Millennials', 'ORG'), ('decades', 'DATE'), ('third', 'ORDINAL'), ('TripAdvisor', 'ORG'), ('7', 'CARDINAL'), ('uploads/2018/01/split-1024x683.jpg', 'PERSON'), ('srcset="https://mk0attractionsiexgba.kinstacdn.com', 'ORG'), ('uploads/2018/01/split-1024x683.jpg 1024w', 'PERSON'), ('300w', 'PRODUCT'), ('https://mk0attractionsiexgba.kinstacdn.com/w ...

# %% [markdown]
# Using `en_core_web_lg` improved the performance, it lables `Facebook` as `ORG`.

# %%
sentences = [x for x in article.sents]
print(sentences[20])
# Out:
# To best position yourself for success, focus on expanding your customer reach and differentiating yourself from competitors in your market.

# %%
displacy.render(nlp(str(sentences[20])), jupyter=True, style='ent')
# Out:
# /Users/nahalam/anaconda3/lib/python3.6/runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# <div class="entities" style="line-height: 2.5">To best position yourself for success, focus on expanding your customer reach and differentiating yourself from competitors in your market.</div>

# %%
displacy.render(nlp(str(sentences[20])), style='dep', jupyter = True, options = {'distance': 120})
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="2450" height="377.0" style="max-width: none; height: 377.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">To</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">best</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">position</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">yourself</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">success,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">focus</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">expanding</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">your</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">customer</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">reach</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">differentiating</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">yourself</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">from</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">competitors</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="2090">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2090">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">your</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="2330">market.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2330">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M70,242.0 C70,122.0 280.0,122.0 280.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,244.0 L62,232.0 78,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-1" stroke-width="2px" d="M190,242.0 C190,182.0 275.0,182.0 275.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-1" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M190,244.0 L182,232.0 198,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-2" stroke-width="2px" d="M310,242.0 C310,62.0 765.0,62.0 765.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-2" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">advcl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M310,244.0 L302,232.0 318,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-3" stroke-width="2px" d="M310,242.0 C310,182.0 395.0,182.0 395.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-3" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M395.0,244.0 L403.0,232.0 387.0,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-4" stroke-width="2px" d="M310,242.0 C310,122.0 520.0,122.0 520.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-4" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M520.0,244.0 L528.0,232.0 512.0,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-5" stroke-width="2px" d="M550,242.0 C550,182.0 635.0,182.0 635.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow

# %%
[(x.orth_,x.pos_, x.lemma_) for x in [y 
                                      for y
                                      in nlp(str(sentences[20])) 
                                      if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [('To', 'PART', 'to'), ('best', 'ADJ', 'good'), ('position', 'VERB', 'position'), ('yourself', 'PRON', '-PRON-'), ('for', 'ADP', 'for'), ('success', 'NOUN', 'success'), ('focus', 'VERB', 'focus'), ('on', 'ADP', 'on'), ('expanding', 'VERB', 'expand'), ('your', 'ADJ', '-PRON-'), ('customer', 'NOUN', 'customer'), ('reach', 'VERB', 'reach'), ('and', 'CCONJ', 'and'), ('differentiating', 'VERB', 'differentiate'), ('yourself', 'PRON', '-PRON-'), ('from', 'ADP', 'from'), ('competitors', 'NOUN', 'competitor'), ('in', 'ADP', 'in'), ('your', 'ADJ', '-PRON-'), ('market', 'NOUN', 'market')]

# %%
dict([(str(x), x.label_) for x in nlp(str(sentences[20])).ents])
# Out:
# {}

# %%
displacy.render(article, jupyter=True, style='ent')
# Out:
# <div class="entities" style="line-height: 2.5"> Top 10 Travel Trends of
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the Year - TripAdvisor Experiences
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
#            HomeManaging My BusinessListingsMarketingTraveler InsightsMoreAboutNews Select
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Page
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# Top 10 Travel Trends of
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the Year–
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
# Plus Key Takeaways For Your Business <img src="https://mk0attractionsiexgba.kinstacdn.com/wp-content/uploads/2018/05/travel-photo-3-Copy.jpg" alt="top travel trends">
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     May 8
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , 2018As a tour operator or attraction owner, staying on top of trends in the rapidly changing travel landscape is critical to helping you make important decisions about your business, including how to better satisfy customers and where to invest your resources. To help you, we’ve taken a look at our own booking data and traveler surveys, combined with research from reputable industry resources, to provide you insight into this
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ’s top travel trends—plus key takeaways for your business.
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# .
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Tours
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and activities are more popular than ever<img class="alignnone wp-image-24694" src="https://mk0attractionsiexgba.kinstacdn.com/wp-content/
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     uploads/2017/11/camels-1024x683.jpg"
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  alt="" width="817" height="545" srcset="https://mk0attractionsiexgba.kinstacdn.com/wp-content/uploads/2017/11/camels-1024x683.jpg
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     1024w
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , https://mk0attractionsiexgba.kinstacdn.com/wp-content/uploads/2017/11/camels-300x200.jpg
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     300w
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# , https://mk0attractionsiexgba.kinstacdn.com/wp-content/uploads/2017/11/camels-768x512.jpg 768w, https://mk0attractionsiexgba.kinstacdn.com/wp-content/uploads/2017/11/camels-1080x720.jpg
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     1080w
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# " sizes="(max-width:
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     817px)
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  100vw, 817px">The overall tours and activities sector is growing quickly; valued at
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     $135 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# , it’s now the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     third
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# -largest travel segment, and is expected to reach
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     $174 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  globally by
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     2020
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . This increase is reflected in the growing investment i

# %% [markdown]
# As seen above, in some cases the entity recognition is not working. For example, it identifies `Page` as `Person` probably because `page` starts with capital `p`. This happens here because there is a `Page` tab in the web link which while data collection came as a text data. So we need more data cleaning.

# %% [markdown]
# ## Reference
#
# 1. spaCy Named Entity Recognition https://spacy.io/usage/linguistic-features
# 2. NLTK - Extracting Information from Text https://www.nltk.org/book/ch07.html
# 2. Wikipedia IOB https://en.wikipedia.org/wiki/Inside%E2%80%93outside%E2%80%93beginning_(tagging)
# 3. Sample project by Susan Li https://towardsdatascience.com/named-entity-recognition-with-nltk-and-spacy-8c4a7d88e7da
